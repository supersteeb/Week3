# %%
import pandas as pd
import numpy as np

# %%
songs_df = pd.read_json('songs_wGenres.json')

# %%
songs_df.drop([])
# Out:
#                                         _id  \
# 0      {'$oid': '52fdfb440b9398049f3d7a8c'}
# 1      {'$oid': '52fdfb3d0b9398049f3cbc8e'}
# 10     {'$oid': '52fdfb430b9398049f3d52a7'}
# 100    {'$oid': '52fdfb3e0b9398049f3ccb47'}
# 1000   {'$oid': '52fdfb400b9398049f3d0bf1'}
# 10000  {'$oid': '52fdfb430b9398049f3d48a1'}
# 10001  {'$oid': '52fdfb3f0b9398049f3cf4b4'}
# 10003  {'$oid': '52fdfb470b9398049f3dbe05'}
# 10004  {'$oid': '52fdfb440b9398049f3d62a8'}
# 10005  {'$oid': '52fdfb420b9398049f3d4221'}
# 10006  {'$oid': '52fdfb460b9398049f3d94f5'}
# 10007  {'$oid': '52fdfb3e0b9398049f3ccc73'}
# 10008  {'$oid': '52fdfb440b9398049f3d705c'}
# 10009  {'$oid': '52fdfb400b9398049f3cfa19'}
# 1001   {'$oid': '52fdfb3e0b9398049f3cc9af'}
# 10010  {'$oid': '52fdfb440b9398049f3d79a2'}
# 10011  {'$oid': '52fdfb460b9398049f3daac9'}
# 10012  {'$oid': '52fdfb3d0b9398049f3cc412'}
# 10013  {'$oid': '52fdfb400b9398049f3d01e5'}
# 10014  {'$oid': '52fdfb440b9398049f3d6d18'}
# ...

# %%
songs_df.loc[:, 'genres'] = songs_df['genres'].apply(''.join)

def consolidateGenre(genre):
    if (len(genre) > 0):
        return genre.split(':')[0]
    else:
        return genre
    
songs_df.loc[:, 'genres'] = songs_df['genres'].apply(consolidateGenre)

# %%
songs_df.head()
# Out:
#                                        _id                         album  \
# 0     {'$oid': '52fdfb440b9398049f3d7a8c'}         Gangnam Style (강남스타일)
# 1     {'$oid': '52fdfb3d0b9398049f3cbc8e'}                        Native
# 10    {'$oid': '52fdfb430b9398049f3d52a7'}                     Na Balada
# 100   {'$oid': '52fdfb3e0b9398049f3ccb47'}  Good Girl Gone Bad: Reloaded
# 1000  {'$oid': '52fdfb400b9398049f3d0bf1'}                  Lost In Love
#
#            artist                                     audio_features  \
# 0             PSY  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1     OneRepublic  [6, 0.7457039999999999, 0.11995499999999999, 1...
# 10    Michel Teló  [11, 0.9030549999999999, 0.6293489999999999, 9...
# 100       Rihanna  [9, 0.46322199999999997, 0.09795799999999999, ...
# 1000   Air Supply  [0, 0.603403, 0.969231, 100.292, 0.027052, 0.3...
#
#                  context  decades genres  \
# 0             [work out]       []    pop
# ...

# %%
unique_genres = []
for genre in songs_df['genres']:
    if genre not in unique_genres:
        unique_genres.append(genre)
print(len(genres_list))
# Out:
# 33057

# %%
print('number of unique genres: ', len(unique_genres))
print(unique_genres)

unique_genre_count = []
for genre in unique_genres:
    count = 0
    for song_genre_list in songs_df['genres']:
        if genre in song_genre_list:
            count = count + 1
    unique_genre_count.append(count)

sum = 0
for genre in unique_genre_count:
    sum = sum + genre
print(sum)

unique_genre_count_dict = {}
for i in range(len(unique_genres)):
    unique_genre_count_dict[unique_genres[i]] = unique_genre_count[i]
print(unique_genre_count_dict)
genre_count = pd.DataFrame.from_dict(data=unique_genre_count_dict, orient='index')
genre_count
# Out:
# number of unique genres:  29
# ['pop', 'latin', 'r&b', 'singer-songwriter', 'jazz', 'dance', 'country', 'reggae & ska', 'rock', 'electronica', 'christian', 'indie', 'classical', 'oldies', 'folk', 'funk', 'rap', 'blues & blues rock', 'reggaeton', 'film scores', 'international/world', "children's", "int'l", "dubstep & drum 'n' bass", 'easy listening', 'showtunes', 'nature sounds', 'bluegrass', 'hawaiian ']
# 33959
# {'pop': 901, 'latin': 1312, 'r&b': 2721, 'singer-songwriter': 1189, 'jazz': 2295, 'dance': 2391, 'country': 1284, 'reggae & ska': 754, 'rock': 8387, 'electronica': 1476, 'christian': 236, 'indie': 2089, 'classical': 1092, 'oldies': 548, 'folk': 487, 'funk': 566, 'rap': 2931, 'blues & blues rock': 902, 'reggaeton': 127, 'film scores': 245, 'international/world': 462, "children's": 260, "int'l": 329, "dubstep & drum 'n' bass": 318, 'easy listening': 196, 'showtunes': 105, 'nature sounds': 34, 'bluegrass': 302, 'hawaiian ': 20}
#                             0
# ...
