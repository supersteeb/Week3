# %%
import pandas as pd
import numpy as np

# %%
songs_df = pd.read_json('MasterSongList.json')

# %%
songs_df.head()
# Out:
#                                     _id                  album  \
# 0  {'$oid': '52fdfb440b9398049f3d7a8c'}  Gangnam Style (강남스타일)
# 1  {'$oid': '52fdfb3d0b9398049f3cbc8e'}                 Native
# 2  {'$oid': '52fdfb420b9398049f3d3ea5'}      Party Rock Anthem
# 3  {'$oid': '52fdfb410b9398049f3d1eac'}              Gentleman
# 4  {'$oid': '52fdfb400b9398049f3d0b19'}           On The Floor
#
#            artist                                     audio_features  \
# 0             PSY  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1     OneRepublic  [6, 0.7457039999999999, 0.11995499999999999, 1...
# 2           LMFAO  [5, 0.709932, 0.231455, 130.03, 0.121740999999...
# 3             PSY  [3, 0.705822, 0.053292, 126.009, 0.126016, 0.0...
# 4  Jennifer Lopez  [3, 0.741757, 0.07277399999999999, 129.985, 0....
#
#                                         context  decades       genres  \
# 0                                    [work out]       []        [pop]
# 1                                   [energetic]   [2012]        [pop]
# 2  [energetic, energetic, energetic, energetic]       []           []
# 3    [party, party, party, party, party, party]  [2010s]      [dance]
# 4                                [party, party]  [2000s]  [reggaeton]
#
#                                      lyrics_features  \
# 0  [oppa, gangnam, style, gangnam, style, najeneu...
# 1  [lately, i, ve, been, i, ve, been, losing, sle...
# 2  [party, rock, yeah, woo, let, s, go, party, ro...
# 3  [alagamun, lan, weh, wakun, heya, hanun, gon, ...
# 4  [j, lo, the, other, side, out, my, mine, it, s...
#
#                              moods                   name new_context  \
# 0        [energetic, motivational]  Gangnam Style (강남스타일)    work out
# 1                          [happy]         Counting Stars   energetic
# 2      [happy, celebratory, rowdy]      Party Rock Anthem   housework
# 3  [happy, energetic, celebratory]              Gentleman   energetic
# 4                      [energetic]           On The Floor    work out
#
#                                              picture  recording_id  \
# 0  http://images.musicnet.com/albums/073/463/405/...       50232.0
# 1  http://images.musicnet.com/albums/081/851/887/...        5839.0
# 2  http://images.musicnet.com/albums/049/414/127/...       52379.0
# 3  http://images.musicnet.com/albums/082/950/461/...       12353.0
# 4  http://images.musicnet.com/albums/050/131/765/...       29502.0
#
#                                          sub_context        yt_id    yt_views
# 0                              [working out: cardio]  9bZkp7q19f0  2450112089
# 1                                     [energy boost]  hT_nvWreIhg  1020297206
# 2  [energy boost, pleasing a crowd, housework, dr...  KQ6zr6kCPj8   971128436
# 3  [driving in the left lane, energy boost, girls...  ASO_zypdnsQ   892096527
# 4         [working out: cardio, dance party: sweaty]  t4H_Zoh7G5A   873285189

# %%
songs_df.loc[:, 'genres'] = songs_df['genres'].apply(''.join)

def consolidateGenre(genre):
    if (len(genre) > 0):
        return genre.split(':')[0]
    else:
        return genre
    
songs_df.loc[:, 'genres'] = songs_df['genres'].apply(consolidateGenre)

# %%
audio_feature_list = []
for song_audio_feature in songs_df['audio_features']:
    audio_feature_list.append(song_audio_feature)

# %%
audio_feature_headers = ['key', 'energy', 'liveliness', 'tempo', 'speechiness', 'acousticness', 'instrumentalness', 'time_signature', 'duration', 'loudness', 'valence', 'danceability', 'mode', 'time_signature_confidence', 'tempo_confidence', 'key_confidence', 'mode_confidence']

# %%
df_features = pd.DataFrame(audio_feature_list, columns=audio_feature_headers)

# %%
df_features['genres'] = songs_df['genres']

# %%
df_features['genres'].replace('',np.NaN, inplace=True)

# %%
df_features.head()
# Out:
#     key    energy  liveliness    tempo  speechiness  acousticness  \
# 0  11.0  0.912744    0.083704  132.069     0.293137      0.005423
# 1   6.0  0.745704    0.119955  100.008     0.046255      0.026230
# 2   5.0  0.709932    0.231455  130.030     0.121741      0.036662
# 3   3.0  0.705822    0.053292  126.009     0.126016      0.001966
# 4   3.0  0.741757    0.072774  129.985     0.051255      0.096732
#
#    instrumentalness  time_signature  duration   loudness  valence  \
# 0          0.000001             0.0       4.0  218.30667   -3.890
# 1          0.012727             1.0       4.0  235.06086   -7.687
# 2          0.000000             0.0       4.0  232.46104   -5.150
# 3          0.000000             0.0       4.0  194.09333   -3.898
# 4          0.000474             0.0       4.0  285.42667   -5.860
#
#    danceability      mode  time_signature_confidence  tempo_confidence  \
# 0      0.752186  0.726920                      0.552             0.541
# 1      0.351282  0.691817                      0.737             0.634
# 2      0.374390  0.704729                      0.565             0.565
# 3      0.592798  0.875137                      0.004             0.114
# 4      0.585630  0.730711                      0.271             0.324
#
#    key_confidence  mode_confidence     genres
# 0           1.000            1.000        pop
# 1           0.796            1.000        pop
# 2           0.743            1.000        NaN
# 3           1.000            0.742      dance
# 4           0.822            1.000  reggaeton

# %%
df_features.dropna(inplace=True)

# %%
df_features_pop = df_features[df_features['genres'] == 'pop'] #689
df_features_not_pop = df_features[df_features['genres'] != 'pop'].sample(n=689)

# %%
df_features_not_pop.loc[df_features_not_pop.genres != 'pop', 'genres'] = 'not pop'

# %%
df_features_popnotpop = pd.concat([df_features_pop, df_features_not_pop], axis=0)

# %%
df_features_popnotpop.reset_index(inplace=True)

# %%
df_features_popnotpop
# Out:
#       index   key    energy  liveliness    tempo  speechiness  acousticness  \
# 0         0  11.0  0.912744    0.083704  132.069     0.293137      0.005423
# 1         1   6.0  0.745704    0.119955  100.008     0.046255      0.026230
# 2         7   7.0  0.585564    0.108297  120.014     0.038924      0.011707
# 3         9   4.0  0.814030    0.079196  124.991     0.072440      0.005355
# 4        12   8.0  0.869554    0.107945  124.065     0.051083      0.132712
# 5        15   5.0  0.838853    0.161256  109.007     0.043218      0.014582
# 6        16   1.0  0.625657    0.418317   80.082     0.034819      0.003484
# 7        17   9.0  0.323877    0.109264  135.116     0.027887      0.893351
# 8        18   3.0  0.640167    0.051898  127.963     0.049790      0.029364
# 9        24   2.0  0.777544    0.063793  100.023     0.073157      0.223289
# 10       26   2.0  0.555380    0.132021   95.000     0.050934      0.397652
# 11       27   5.0  0.785597    0.186539  175.041     0.147627      0.021278
# 12       29   7.0  0.736727    0.069281  125.928     0.044913      0.054524
# 13       31   5.0  0.588633    0.622563  160.009     0.036844      0.101109
# 14       32   9.0  0.670427    0.320679  136.248     0.064177      0.140495
# 15       33   8.0  0.901215    0.411150  130.045     0.056173      0.147293
# 16       34   5.0  0.805683    0.100479   80.037     0.048322      0.009075
# 17       35   1.0  0.877174    0.069938  118.499     0.044953      0.024998
# 18       39   5.0  0.897456    0.357827  130.039     0.035507      0.000470
# 19       40   8.0  0.787443    0.238319  173.929     0.106064      0.089858
# 20       41  11.0  0.941485    0.750843  146.222     0.118968      0.053169
# 21       42   0.0  0.301757    0.091785   72.984     0.038889      0.905122
# 22       43   0.0  0.789290    0.233245  124.995     0.083371      0.002485
# 23       44  10.0  0.434386    0.116101  139.314     0.027333      0.280126
# 24       48   8.0  0.828606    0.099442  127.908     0.183028      0.005767
# 25       51   2.0  0.834624    0.081987  150.017     0.048595      0.336994
# 26       52   2.0  0.670387    0.111632  107.995     0.024908      0.004081
# 1376      0.068926  0.241169                      0.781             0.665
# 1377      0.430878  0.740000                      0.419             0.593
#
#       key_confidence  mode_confidence   genres
# 0              1.000            1.000      pop
# 1              0.796            1.000      pop
# 2              0.792            1.000      pop
# 3              0.740            1.000      pop
# 4              0.669            1.000      pop
# 5              0.577            0.995      pop
# 6              0.000            1.000      pop
# 7              0.465            0.720      pop
# 8              0.858            1.000      pop
# 9              0.595            1.000      pop
# 10             0.414            1.000      pop
# 11             0.417            1.000      pop
# 12             0.957            1.000      pop
# 13             0.149            1.000      pop
# 14             0.423            1.000      pop
# 15             0.541            1.000      pop
# 16             0.151            1.000      pop
# 17             0.713            1.000      pop
# 18             0.932            1.000      pop
# 19             0.292            1.000      pop
# 20             0.886            0.793      pop
# 21             0.098            0.545      pop
# 22             0.500            1.000      pop
# 23             0.377            1.000      pop
# 24             0.792            1.000      pop
# 25             0.280            0.165      pop
# 26             0.858            0.878      pop
# 27             0.158            0.809      pop
# 28             0.032            1.000      pop
# 29             0.783            1.000      pop
# ...              ...              ...      ...
# 1348           0.921            0.996  not pop
# 1349           0.539            0.889  not pop
# 1350           0.138            0.712  not pop
# 1351           0.047            1.000  not pop
# 1352           0.275            1.000  not pop
# 1353           0.605            0.157  not pop
# 1354           0.241            0.732  not pop
# 1355           0.081            0.917  not pop
# 1356           0.234            0.374  not pop
# 1357           0.277            0.927  not pop
# 1358           0.198            0.488  not pop
# 1359           0.836            1.000  not pop
# 1360           0.570            1.000  not pop
# 1361           0.248            1.000  not pop
# 1362           0.222            1.000  not pop
# 1363           0.360            0.557  not pop
# 1364           0.980            1.000  not pop
# 1365           0.895            0.812  not pop
# 1366           0.087            0.818  not pop
# 1367           0.635            0.918  not pop
# 1368           0.777            0.762  not pop
# 1369           0.316            0.938  not pop
# 1370           0.393            1.000  not pop
# 1371           0.670            0.788  not pop
# 1372           0.143            0.960  not pop
# 1373           0.249            1.000  not pop
# 1374           0.477            0.980  not pop
# 1375           0.892            1.000  not pop
# 1376           0.123            1.000  not pop
# 1377           0.541            0.663  not pop
#
# [1378 rows x 19 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df_features_popnotpop.drop('genres', axis=1)
y = df_features_popnotpop['genres']

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X, y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

rfc = RandomForestClassifier()
selector = SelectKBest()
knn = KNeighborsClassifier()
svc = SVC()
logReg = LogisticRegression()

# %% [markdown]
# # importing genrePopNotPop_votingClassifier

# %%
genrePopNotPop_votingClassifier = VotingClassifier([('<knn>', knn), ('<svc>', svc), ('<logReg>', logReg), ('<rfc>', rfc)])

# %%
genrePopNotPop_votingClassifier.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('<knn>', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')), ('<svc>', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, ga...n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))],
#          flatten_transform=None, n_jobs=1, voting='hard', weights=None)

# %%
y_predictions = votingClassifier.predict(X_test)
# Out:
# /Users/Steve/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, y_predictions))
# Out:
# 0.7427536231884058

# %%
# need to optimize

# %%
#pickle here to be imported into function
