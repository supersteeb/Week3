# %%
import pandas as pd
import numpy as np

# %%
songs_df = pd.read_json('MasterSongList.json')

# %%
songs_df.head()
# Out:
#                                     _id                  album  \
# 0  {'$oid': '52fdfb440b9398049f3d7a8c'}  Gangnam Style (강남스타일)
# 1  {'$oid': '52fdfb3d0b9398049f3cbc8e'}                 Native
# 2  {'$oid': '52fdfb420b9398049f3d3ea5'}      Party Rock Anthem
# 3  {'$oid': '52fdfb410b9398049f3d1eac'}              Gentleman
# 4  {'$oid': '52fdfb400b9398049f3d0b19'}           On The Floor
#
#            artist                                     audio_features  \
# 0             PSY  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1     OneRepublic  [6, 0.7457039999999999, 0.11995499999999999, 1...
# 2           LMFAO  [5, 0.709932, 0.231455, 130.03, 0.121740999999...
# 3             PSY  [3, 0.705822, 0.053292, 126.009, 0.126016, 0.0...
# 4  Jennifer Lopez  [3, 0.741757, 0.07277399999999999, 129.985, 0....
#
#                                         context  decades       genres  \
# 0                                    [work out]       []        [pop]
# 1                                   [energetic]   [2012]        [pop]
# 2  [energetic, energetic, energetic, energetic]       []           []
# 3    [party, party, party, party, party, party]  [2010s]      [dance]
# 4                                [party, party]  [2000s]  [reggaeton]
#
#                                      lyrics_features  \
# 0  [oppa, gangnam, style, gangnam, style, najeneu...
# 1  [lately, i, ve, been, i, ve, been, losing, sle...
# 2  [party, rock, yeah, woo, let, s, go, party, ro...
# 3  [alagamun, lan, weh, wakun, heya, hanun, gon, ...
# 4  [j, lo, the, other, side, out, my, mine, it, s...
#
#                              moods                   name new_context  \
# 0        [energetic, motivational]  Gangnam Style (강남스타일)    work out
# 1                          [happy]         Counting Stars   energetic
# 2      [happy, celebratory, rowdy]      Party Rock Anthem   housework
# 3  [happy, energetic, celebratory]              Gentleman   energetic
# 4                      [energetic]           On The Floor    work out
#
#                                              picture  recording_id  \
# 0  http://images.musicnet.com/albums/073/463/405/...       50232.0
# 1  http://images.musicnet.com/albums/081/851/887/...        5839.0
# 2  http://images.musicnet.com/albums/049/414/127/...       52379.0
# 3  http://images.musicnet.com/albums/082/950/461/...       12353.0
# 4  http://images.musicnet.com/albums/050/131/765/...       29502.0
#
#                                          sub_context        yt_id    yt_views
# 0                              [working out: cardio]  9bZkp7q19f0  2450112089
# 1                                     [energy boost]  hT_nvWreIhg  1020297206
# 2  [energy boost, pleasing a crowd, housework, dr...  KQ6zr6kCPj8   971128436
# 3  [driving in the left lane, energy boost, girls...  ASO_zypdnsQ   892096527
# 4         [working out: cardio, dance party: sweaty]  t4H_Zoh7G5A   873285189

# %%
songs_df.loc[:, 'genres'] = songs_df['genres'].apply(''.join)

def consolidateGenre(genre):
    if (len(genre) > 0):
        return genre.split(':')[0]
    else:
        return genre
    
songs_df.loc[:, 'genres'] = songs_df['genres'].apply(consolidateGenre)

# %%
audio_feature_list = []
for song_audio_feature in songs_df['audio_features']:
    audio_feature_list.append(song_audio_feature)

# %%
audio_feature_headers = ['key', 'energy', 'liveliness', 'tempo', 'speechiness', 'acousticness', 'instrumentalness', 'time_signature', 'duration', 'loudness', 'valence', 'danceability', 'mode', 'time_signature_confidence', 'tempo_confidence', 'key_confidence', 'mode_confidence']

# %%
df_features = pd.DataFrame(audio_feature_list, columns=audio_feature_headers)

# %%
df_features['genres'] = songs_df['genres']

# %%
df_features['genres'].unique()
# Out:
# array(['pop', '', 'dance', 'reggaeton', 'r&b', 'latin', 'rock',
#        'singer-songwriter', 'rap', 'international/world', 'indie', 'jazz',
#        'country', 'folk', 'reggae & ska', "children's", 'electronica',
#        'hawaiian ', 'funk', 'blues & blues rock', 'showtunes',
#        'christian', "dubstep & drum 'n' bass", 'classical', 'oldies',
#        'easy listening', 'film scores', 'nature sounds', "int'l",
#        'bluegrass'], dtype=object)

# %%
df_features['genres'].replace('',np.NaN, inplace=True)

# %%
df_features.head()
# Out:
#     key    energy  liveliness    tempo  speechiness  acousticness  \
# 0  11.0  0.912744    0.083704  132.069     0.293137      0.005423
# 1   6.0  0.745704    0.119955  100.008     0.046255      0.026230
# 2   5.0  0.709932    0.231455  130.030     0.121741      0.036662
# 3   3.0  0.705822    0.053292  126.009     0.126016      0.001966
# 4   3.0  0.741757    0.072774  129.985     0.051255      0.096732
#
#    instrumentalness  time_signature  duration   loudness  valence  \
# 0          0.000001             0.0       4.0  218.30667   -3.890
# 1          0.012727             1.0       4.0  235.06086   -7.687
# 2          0.000000             0.0       4.0  232.46104   -5.150
# 3          0.000000             0.0       4.0  194.09333   -3.898
# 4          0.000474             0.0       4.0  285.42667   -5.860
#
#    danceability      mode  time_signature_confidence  tempo_confidence  \
# 0      0.752186  0.726920                      0.552             0.541
# 1      0.351282  0.691817                      0.737             0.634
# 2      0.374390  0.704729                      0.565             0.565
# 3      0.592798  0.875137                      0.004             0.114
# 4      0.585630  0.730711                      0.271             0.324
#
#    key_confidence  mode_confidence     genres
# 0           1.000            1.000        pop
# 1           0.796            1.000        pop
# 2           0.743            1.000        NaN
# 3           1.000            0.742      dance
# 4           0.822            1.000  reggaeton

# %%
df_features.dropna(inplace=True)

# %%
df_features.shape
# Out:
# (27161, 18)

# %%
df_features_rap = df_features[df_features['genres'] == 'rap']

# %%
df_features_rap.shape
# Out:
# (2452, 18)

# %%
df_features_rap['genres_simplified'] = 'rap'
# Out:
# /Users/Steve/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # make sure sample is same amount of the genre amount (balancing data)
# ('classical' => 2452)

# %%
df_features_not_rap = df_features[df_features['genres'] != 'rap'].sample(n=2452)

# %%
df_features_not_rap['genres_simplified'] = 'not rap'

# %%
df_features_RapNotRap = pd.concat([df_features_rap, df_features_not_rap], axis=0)

# %%
df_features_RapNotRap.reset_index(inplace=True)

# %%
df_features_RapNotRap
# Out:
#       index   key    energy  liveliness    tempo  speechiness  acousticness  \
# 0        53  11.0  0.682443    0.163735  146.216     0.183496      0.030170
# 1        55   6.0  0.722723    0.074246   89.999     0.340797      0.260922
# 2        89   2.0  0.832268    0.273200  164.070     0.059476      0.061904
# 3        98   8.0  0.511694    0.159764   86.350     0.187572      0.037796
# 4       115  11.0  0.324839    0.325669  121.379     0.655687      0.030058
# 5       118   5.0  0.816507    0.212694  129.975     0.110272      0.000264
# 6       120   6.0  0.831990    0.464863  170.237     0.392644      0.040739
# 7       132   1.0  0.906022    0.341704  145.048     0.324825      0.070587
# 8       133   1.0  0.446286    0.499771  104.044     0.143111      0.006503
# 9       142   0.0  0.518301    0.089267  117.364     0.349597      0.028045
# 10      145   8.0  0.643952    0.121978  124.951     0.034232      0.011873
# 11      148  10.0  0.674971    0.060643  140.043     0.212844      0.050310
# 12      160   3.0  0.828215    0.131678  114.725     0.069248      0.166942
# 13      174   1.0  0.790401    0.226377  142.154     0.054368      0.102046
# 14      183   2.0  0.850453    0.192271  114.011     0.068293      0.080688
# 15      187   1.0  0.352378    0.105419  142.974     0.193916      0.099264
# 16      209  11.0  0.674659    0.261503  139.977     0.065540      0.118406
# 17      223   1.0  0.884130    0.191139  140.077     0.243444      0.094240
# 18      224   6.0  0.551214    0.053672  146.092     0.317351      0.048771
# 19      231   6.0  0.943519    0.973526   86.115     0.308485      0.759008
# 20      235  11.0  0.778863    0.181262  126.036     0.291368      0.062345
# 21      245  10.0  0.755668    0.043947   78.888     0.352267      0.034580
# 5              0.680            1.000                rap               rap
# 6              0.095            1.000                rap               rap
# 7              0.107            1.000                rap               rap
# 8              0.551            1.000                rap               rap
# 9              0.530            0.563                rap               rap
# 10             0.347            1.000                rap               rap
# 11             0.595            0.070                rap               rap
# 12             0.789            1.000                rap               rap
# 13             0.294            1.000                rap               rap
# 14             0.914            0.963                rap               rap
# 15             0.439            0.982                rap               rap
# 16             0.665            1.000                rap               rap
# 17             0.314            0.946                rap               rap
# 18             0.125            0.975                rap               rap
# 19             0.108            0.876                rap               rap
# 20             0.900            1.000                rap               rap
# 21             0.539            0.781                rap               rap
# 22             0.045            1.000                rap               rap
# 23             0.703            0.929                rap               rap
# 24             0.450            0.984                rap               rap
# 25             0.542            1.000                rap               rap
# 26             0.493            0.994                rap               rap
# 27             0.352            1.000                rap               rap
# 28             0.831            1.000                rap               rap
# 29             0.891            1.000                rap               rap
# ...              ...              ...                ...               ...
# 4874           0.907            1.000               rock           not rap
# 4875           0.382            0.562               rock           not rap
# 4876           0.162            0.915               rock           not rap
# 4877           0.084            1.000                r&b           not rap
# 4878           0.126            0.934               rock           not rap
# 4879           0.888            1.000        electronica           not rap
# 4880           0.849            1.000            country           not rap
# 4881           0.300            0.994              indie           not rap
# 4882           0.423            0.986              dance           not rap
# 4883           0.898            1.000              latin           not rap
# 4884           0.295            0.220             oldies           not rap
# 4885           0.870            1.000  singer-songwriter           not rap
# 4886           0.743            0.928              dance           not rap
# 4887           0.552            0.880  singer-songwriter           not rap
# 4888           0.740            0.859              indie           not rap
# 4889           0.124            0.122              indie           not rap
# 4890           0.817            1.000               funk           not rap
# 4891           0.967            0.897  singer-songwriter           not rap
# 4892           1.000            0.910              indie           not rap
# 4893           0.235            1.000       reggae & ska           not rap
# 4894           0.965            0.926  singer-songwriter           not rap
# 4895           0.916            1.000               rock           not rap
# 4896           0.474            0.747               rock           not rap
# 4897           0.383            1.000               rock           not rap
# 4898           0.697            0.858            country           not rap
# 4899           0.092            0.932          bluegrass           not rap
# 4900           0.230            1.000       reggae & ska           not rap
# 4901           0.691            1.000                r&b           not rap
# 4902           0.826            1.000              indie           not rap
# 4903           0.858            1.000                r&b           not rap
#
# [4904 rows x 20 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df_features_RapNotRap.drop(['genres', 'genres_simplified'], axis=1)
y = df_features_RapNotRap['genres_simplified']

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X, y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

rfc = RandomForestClassifier()
selector = SelectKBest()
knn = KNeighborsClassifier()
svc = SVC()
logReg = LogisticRegression()

# %% [markdown]
# # importing genreRapNotRap_votingClassifier

# %%
genreRapNotRap_votingClassifier = VotingClassifier([('<knn>', knn), ('<svc>', svc), ('<logReg>', logReg), ('<rfc>', rfc)])

# %%
af_RapNotRap = genreRapNotRap_votingClassifier.fit(X_train, y_train)

# %%
y_predictions_RapNotRap = genreRapNotRap_votingClassifier.predict(X_test)
# Out:
# /Users/Steve/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, y_predictions_RapNotRap)) #84.7
# Out:
# 0.8470948012232415

# %%
# need to optimize

# %%
#pickle here to be imported into function

# %%
import pickle

# %%
pickle.dump(af_RapNotRap, open('genre_af_RapNotRap.pickle', 'wb')) #need to re-export after optimization
